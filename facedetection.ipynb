# %%
# Following https://www.datacamp.com/community/tutorials/face-detection-python-opencv
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline


test_image = cv2.imread('img/DANCE.JPG')

#Converting to grayscale
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# Displaying the grayscale image
plt.imshow(test_image_gray, cmap='gray')

# %%
# Following https://www.datacamp.com/community/tutorials/face-detection-python-opencv
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


test_image = cv2.imread('img/DANCE.JPG')

#Converting to grayscale
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# Displaying the grayscale image
plt.imshow(test_image_gray, cmap='gray')


haar_cascade_face = cv2.CascadeClassifier('data/haarcascade/haarcascade_frontalface_default.xml')

faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor = 1.2, minNeighbors = 5);

# Let us print the no. of faces found
print('Faces found: ', len(faces_rects))

# create a copy of the image to prevent any changes to the original one.
image_copy = test_image.copy()

#convert the test image to gray scale as opencv face detector expects gray images
gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)

# Applying the haar classifier to detect faces
faces_rect = haar_cascade_face.detectMultiScale(gray_image, scaleFactor, minNeighbors=5)

for (x, y, w, h) in faces_rect:
    cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)

#convert image to RGB and show image

plt.imshow(convertToRGB(image_copy))  


dance_image = convertToRGB(image_copy)

filename_face_detected = os.path.join('/Users/jmukherj/Documents/research/python', 'DANCE_FACE_DETECTED.JPG')
imageio.imwrite(filename_face_detected, dance_image)
# Out:
# Faces found:  2

# %%
# Following https://www.datacamp.com/community/tutorials/face-detection-python-opencv
import numpy as np
import cv2
import matplotlib.pyplot as plt
import imageio 
import os 

def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


test_image = cv2.imread('img/aayan/Aayan.jpg')

#Converting to grayscale
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# Displaying the grayscale image
plt.imshow(test_image_gray, cmap='gray')

scaleFactor = 1.2

haar_cascade_face = cv2.CascadeClassifier('data/haarcascade/haarcascade_frontalface_default.xml')

faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor, minNeighbors = 5);

# Let us print the no. of faces found
print('Faces found: ', len(faces_rects))


# create a copy of the image to prevent any changes to the original one.
image_copy = test_image.copy()

#convert the test image to gray scale as opencv face detector expects gray images
gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)

# Applying the haar classifier to detect faces
faces_rect = haar_cascade_face.detectMultiScale(gray_image, scaleFactor, minNeighbors=5)

for (x, y, w, h) in faces_rect:
    cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)

#convert image to RGB and show image

plt.imshow(convertToRGB(image_copy))  


aayan_oci_image = convertToRGB(image_copy)

filename_face_detected = os.path.join('/Users/jmukherj/Documents/research/python', 'aayan_oci_image_FACE_DETECTED.JPG')
imageio.imwrite(filename_face_detected, aayan_oci_image)
# Out:
# Faces found:  6

# %%
# Following https://www.datacamp.com/community/tutorials/face-detection-python-opencv
import numpy as np
import cv2
import matplotlib.pyplot as plt
import imageio 
import os 

def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


test_image = cv2.imread('img/aayan/profile_aayan.jpg')

#Converting to grayscale
test_image_gray = cv2.cvtColor(test_image, cv2.COLOR_BGR2GRAY)

# Displaying the grayscale image
plt.imshow(test_image_gray, cmap='gray')

scaleFactor = 1.2

haar_cascade_face = cv2.CascadeClassifier('data/haarcascade/haarcascade_frontalface_default.xml')

faces_rects = haar_cascade_face.detectMultiScale(test_image_gray, scaleFactor, minNeighbors = 5);

# Let us print the no. of faces found
print('Faces found: ', len(faces_rects))


# create a copy of the image to prevent any changes to the original one.
image_copy = test_image.copy()

#convert the test image to gray scale as opencv face detector expects gray images
gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)

# Applying the haar classifier to detect faces
faces_rect = haar_cascade_face.detectMultiScale(gray_image, scaleFactor, minNeighbors=5)

for (x, y, w, h) in faces_rect:
    cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)

#convert image to RGB and show image

plt.imshow(convertToRGB(image_copy))  


aayan_profile_image = convertToRGB(image_copy)

filename_face_detected = os.path.join('/Users/jmukherj/Documents/research/python', 'aayan_profile_FACE_DETECTED.JPG')
imageio.imwrite(filename_face_detected, aayan_profile_image)
# Out:
# Faces found:  1
